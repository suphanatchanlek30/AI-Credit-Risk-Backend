# %% [markdown]
# - <a href='#1'>Prepare</a>
# - <a href='#2'>Feature Selection</a>
#     - <a href='#2-1'>1. Filter</a>
#         - <a href='#2-1-1'>1.1 Pearson Correlation</a>
#         - <a href='#2-1-2'>1.2 Chi-2</a>
#     - <a href='#2-2'>2. Wrapper</a>
#     - <a href='#2-3'>3. Embeded</a>
#         - <a href='#2-3-1'>3.1 Logistics Regression L1</a>
#         - <a href='#2-3-2'>3.2 Random Forest</a>
#         - <a href='#2-3-3'>3.3 LightGBM</a>
# - <a href='#3'>Summary</a>

# %% [markdown]
# # <a id='1'>Prepare</a>

# %%
import pandas as pd
import numpy as np
import gc
import warnings
warnings.filterwarnings("ignore")
application_train = pd.read_csv('input/application_train.csv')

# %% [markdown]
# ### Stratified Sampling (ratio = 0.1)

# %%
application_sample1 = application_train.loc[application_train.TARGET==1].sample(frac=0.1, replace=False)
print('label 1 sample size:', str(application_sample1.shape[0]))
application_sample0 = application_train.loc[application_train.TARGET==0].sample(frac=0.1, replace=False)
print('label 0 sample size:', str(application_sample0.shape[0]))
application = pd.concat([application_sample1, application_sample0], axis=0).sort_values('SK_ID_CURR')
# Out:
# label 1 sample size: 2482
# label 0 sample size: 28269

# %% [markdown]
# ### Impute missing values

# %%
categorical_list = []
numerical_list = []
for i in application.columns.tolist():
    if application[i].dtype=='object':
        categorical_list.append(i)
    else:
        numerical_list.append(i)
print('Number of categorical features:', str(len(categorical_list)))
print('Number of numerical features:', str(len(numerical_list)))
# Out:
# Number of categorical features: 16
# Number of numerical features: 106

# %%
from sklearn.impute import SimpleImputer
application[numerical_list] = SimpleImputer(strategy='median').fit_transform(application[numerical_list])

# %% [markdown]
# ### Deal with Categorical features: OneHotEncoding

# %%
del application_train; gc.collect()
application = pd.get_dummies(application, drop_first=True)
print(application.shape)
# Out:
# (30751, 227)

# %% [markdown]
# ### Feature matrix and target

# %%
X = application.drop(['SK_ID_CURR', 'TARGET'], axis=1)
y = application.TARGET
feature_name = X.columns.tolist()

# %% [markdown]
# # <a id='2'>Feature Selection</a>
# - select **100** features from 226
# - **xxx_support**: list to represent select this feature or not
# - **xxx_feature**: the name of selected features

# %% [markdown]
# ## <a id='2-1'>1 Filter</a>
# - documentation for **SelectKBest**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html
#
# ###  <a id='2-1-1'>1.1 Pearson Correlation</a>
# **Note**
# - Normalization: no
# - Impute missing values: yes

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ###  <a id='2-1-2'>1.2 Chi-2</a>
#
# **Note**
# - Normalization: MinMaxScaler (values should be bigger than 0)
# - Impute missing values: yes

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x0000018563E0D3A0>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-2'>2. Wrapper</a>
# - documentation for **RFE**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#
# **Note**
# - Normalization: depend on the used model; yes for LR
# - Impute missing values: depend on the used model; yes for LR

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 225 features.
# Fitting estimator with 215 features.
# Fitting estimator with 205 features.
# Fitting estimator with 195 features.
# Fitting estimator with 185 features.
# Fitting estimator with 175 features.
# Fitting estimator with 165 features.
# Fitting estimator with 155 features.
# Fitting estimator with 145 features.
# Fitting estimator with 135 features.
# Fitting estimator with 125 features.
# Fitting estimator with 115 features.
# Fitting estimator with 105 features.
# RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10,
#     verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-3'>3. Embeded</a>
# - documentation for **SelectFromModel**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
# ###  <a id='2-3-1'>3.1 Logistics Regression L1</a>
# **Note**
# - Normalization: Yes
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(
    LogisticRegression(
        penalty='l1',
        solver='liblinear',
        random_state=42,
        max_iter=1000
    ),
    threshold='1.25*median'
)

embeded_lr_selector.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LogisticRegression(max_iter=1000, penalty='l1',
#                                              random_state=42,
#                                              solver='liblinear'),
#                 threshold='1.25*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 106 selected features

# %% [markdown]
# ###  <a id='2-3-2'>3.2 Random Forest</a>
# **Note**
# - Normalization: No
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(), threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 98 selected features

# %% [markdown]
# ###  <a id='2-3-3'>3.3 LightGBM</a>
# **Note**
# - Normalization: No
# - Impute missing values: No

# %%
import re

X_lgb = X.copy()
X_lgb.columns = [
    re.sub(r'[^A-Za-z0-9_]+', '_', str(col))
    for col in X_lgb.columns
]

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc = LGBMClassifier(
    n_estimators=500,
    learning_rate=0.05,
    num_leaves=32,
    colsample_bytree=0.2,
    reg_alpha=3,
    reg_lambda=1,
    min_split_gain=0.01,
    min_child_weight=40,
    random_state=42
)

embeded_lgb_selector = SelectFromModel(lgbc, threshold='1.25*median')
embeded_lgb_selector.fit(X_lgb, y)
# Out:
# [LightGBM] [Info] Number of positive: 2482, number of negative: 28269
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10627
# [LightGBM] [Info] Number of data points in the train set: 30751, number of used features: 207
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080713 -> initscore=-2.432701
# [LightGBM] [Info] Start training from score -2.432701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# SelectFromModel(estimator=LGBMClassifier(colsample_bytree=0.2,
#                                          learning_rate=0.05,
#                                          min_child_weight=40,
#                                          min_split_gain=0.01, n_estimators=500,
#                                          num_leaves=32, random_state=42,
#                                          reg_alpha=3, reg_lambda=1),
#                 threshold='1.25*median')

# %%
embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 108 selected features

# %% [markdown]
# # <a id='3'>Summary</a>

# %%
pd.set_option('display.max_rows', None)

feature_selection_df = pd.DataFrame({
    'Feature': feature_name,
    'Pearson': cor_support,
    'Chi-2': chi_support,
    'RFE': rfe_support,
    'Logistics': embeded_lr_support,
    'Random Forest': embeded_rf_support,
    'LightGBM': embeded_lgb_support
})

selection_cols = ['Pearson', 'Chi-2', 'RFE', 'Logistics', 'Random Forest', 'LightGBM']
feature_selection_df['Total'] = feature_selection_df[selection_cols].sum(axis=1)

feature_selection_df = feature_selection_df.sort_values(['Total', 'Feature'], ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df) + 1)

feature_selection_df.head(100)
# Out:
#                                                Feature  Pearson  Chi-2    RFE  \
# 1                                       TOTALAREA_MODE     True   True   True
# 2                          REGION_RATING_CLIENT_W_CITY     True   True   True
# 3                                 REGION_RATING_CLIENT     True   True   True
# 4                      ORGANIZATION_TYPE_Self-employed     True   True   True
# 5             ORGANIZATION_TYPE_Business Entity Type 3     True   True   True
# 6                                   NONLIVINGAREA_MODE     True   True   True
# 7                  NAME_HOUSING_TYPE_House / apartment     True   True   True
# 8                 NAME_EDUCATION_TYPE_Higher education     True   True   True
# 9                                       FLOORSMAX_MODE     True   True   True
# 10                                      FLAG_OWN_CAR_Y     True   True   True
# 11                                     FLAG_DOCUMENT_3     True   True   True
# 12                                        EXT_SOURCE_3     True   True   True
# 13                                        EXT_SOURCE_2     True   True   True
# 14                                        EXT_SOURCE_1     True   True   True
# 15                            DEF_60_CNT_SOCIAL_CIRCLE     True   True   True
# 16                            DEF_30_CNT_SOCIAL_CIRCLE     True   True   True
# 17                              DAYS_LAST_PHONE_CHANGE     True   True   True
# 18                                     DAYS_ID_PUBLISH     True   True   True
# 19                                          DAYS_BIRTH     True   True   True
# 20                                       CODE_GENDER_M     True   True   True
# 21                                     AMT_GOODS_PRICE     True   True   True
# 22                WEEKDAY_APPR_PROCESS_START_WEDNESDAY     True   True  False
# 23                              REG_CITY_NOT_LIVE_CITY     True   True  False
# 24               OCCUPATION_TYPE_High skill tech staff     True   True   True
# 25                             OCCUPATION_TYPE_Drivers     True   True  False
# 26                            NAME_INCOME_TYPE_Working     True   True  False
# 27                          NAME_INCOME_TYPE_Pensioner     True   True   True
# 28                      NAME_HOUSING_TYPE_With parents     True   True   True
# 29                        NAME_FAMILY_STATUS_Separated    False   True   True
# 30                          NAME_FAMILY_STATUS_Married     True   True  False
# 31                  NAME_CONTRACT_TYPE_Revolving loans     True   True   True
# 32                                     LIVINGAREA_MODE     True   True   True
# 33                                      LIVINGAREA_AVG     True   True   True
# 34                             HOUR_APPR_PROCESS_START     True  False   True
# 35                                      FLOORSMIN_MODE     True  False   True
# 36                                      FLOORSMAX_MEDI     True   True   True
# 37                                       FLOORSMAX_AVG     True   True   True
# 38                                     FLAG_WORK_PHONE     True   True  False
# 39                                          FLAG_PHONE     True   True  False
# 40                                     FLAG_DOCUMENT_6     True   True   True
# 41                                      ENTRANCES_MODE     True  False   True
# 42                                       ELEVATORS_AVG     True   True   True
# 43                                   DAYS_REGISTRATION     True  False   True
# 44                                        CNT_CHILDREN     True   True  False
# 45                           AMT_REQ_CREDIT_BUREAU_MON     True  False   True
# 46                                          AMT_CREDIT     True   True  False
# 47                                         AMT_ANNUITY     True  False   True
# 48                                    YEARS_BUILD_MEDI     True  False  False
# 49                        YEARS_BEGINEXPLUATATION_MEDI    False  False   True
# 50                         YEARS_BEGINEXPLUATATION_AVG    False  False   True
# 51                 WEEKDAY_APPR_PROCESS_START_SATURDAY    False   True  False
# 52                              REG_CITY_NOT_WORK_CITY     True   True  False
# 53                          REGION_POPULATION_RELATIVE     True   True  False
# 54                 ORGANIZATION_TYPE_Transport: type 3     True   True   True
# 55                 ORGANIZATION_TYPE_Transport: type 2     True   True   True
# 56               ORGANIZATION_TYPE_Security Ministries     True   True   True
# 57                            ORGANIZATION_TYPE_Police     True   True   True
# 58                 ORGANIZATION_TYPE_Industry: type 11     True   True   True
# 59            ORGANIZATION_TYPE_Business Entity Type 2    False   True   True
# 60                            OCCUPATION_TYPE_Laborers     True   True  False
# 61                          OCCUPATION_TYPE_Core staff     True   True  False
# 62                            OBS_30_CNT_SOCIAL_CIRCLE    False  False   True
# 63                                  NONLIVINGAREA_MEDI     True   True  False
# 64                                   NONLIVINGAREA_AVG     True   True  False
# 65               NAME_INCOME_TYPE_Commercial associate     True   True  False
# 66                  NAME_HOUSING_TYPE_Rented apartment     True   True   True
# 67                            NAME_FAMILY_STATUS_Widow     True   True  False
# 68   NAME_EDUCATION_TYPE_Secondary / secondary special     True   True  False
# 69                                     LIVINGAREA_MEDI     True   True  False
# 70                               LIVINGAPARTMENTS_MODE     True  False   True
# 71                               LIVINGAPARTMENTS_MEDI     True  False   True
# 72                                       LANDAREA_MEDI    False  False   True
# 73                 FONDKAPREMONT_MODE_org spec account     True   True   True
# 74                                      ENTRANCES_MEDI     True  False   True
# 75                                       ENTRANCES_AVG     True  False   True
# 76                                       DAYS_EMPLOYED     True   True  False
# 77                                     APARTMENTS_MEDI     True   True  False
# 78                                      APARTMENTS_AVG     True   True  False
# 79                          AMT_REQ_CREDIT_BUREAU_YEAR    False  False   True
# 80                                    YEARS_BUILD_MODE     True  False  False
# 81                                     YEARS_BUILD_AVG     True  False  False
# 82                           WALLSMATERIAL_MODE_Wooden     True   True  False
# 83                            WALLSMATERIAL_MODE_Panel     True   True  False
# 84                     ORGANIZATION_TYPE_Trade: type 6    False   True   True
# 85                     ORGANIZATION_TYPE_Trade: type 3    False   True   True
# 86                     ORGANIZATION_TYPE_Trade: type 2    False   True   True
# 87                      ORGANIZATION_TYPE_Kindergarten    False   True   True
# 88                  ORGANIZATION_TYPE_Industry: type 5    False   True   True
# 89                           ORGANIZATION_TYPE_Housing    False   True   True
# 90                        ORGANIZATION_TYPE_Government    False  False   True
# 91                         OCCUPATION_TYPE_Sales staff     True   True  False
# 92                            OBS_60_CNT_SOCIAL_CIRCLE    False  False   True
# 93                     NAME_TYPE_SUITE_Group of people    False   True   True
# 94                      NAME_INCOME_TYPE_State servant     True   True  False
# 95               NAME_HOUSING_TYPE_Municipal apartment    False  False   True
# 96             NAME_FAMILY_STATUS_Single / not married     True   True  False
# 97                 NAME_EDUCATION_TYPE_Lower secondary    False   True   True
# 98                                LIVINGAPARTMENTS_AVG     True  False  False
# 99                             LIVE_CITY_NOT_WORK_CITY     True   True  False
# 100                                      LANDAREA_MODE    False  False   True
#
#      Logistics  Random Forest  LightGBM  Total
# 1         True           True      True      6
# 2         True           True      True      6
# 3         True           True      True      6
# 4         True           True      True      6
# 5         True           True      True      6
# 6         True           True      True      6
# 7         True           True      True      6
# 8         True           True      True      6
# 9         True           True      True      6
# 10        True           True      True      6
# 11        True           True      True      6
# 12        True           True      True      6
# 13        True           True      True      6
# 14        True           True      True      6
# 15        True           True      True      6
# 16        True           True      True      6
# 17        True           True      True      6
# 18        True           True      True      6
# 19        True           True      True      6
# 20        True           True      True      6
# 21        True           True      True      6
# 22        True           True      True      5
# 23        True           True      True      5
# 24        True          False      True      5
# 25        True           True      True      5
# 26        True           True      True      5
# 27        True          False      True      5
# 28        True           True     False      5
# 29        True           True      True      5
# 30        True           True      True      5
# 31        True          False      True      5
# 32       False           True      True      5
# 33       False           True      True      5
# 34        True           True      True      5
# 35        True           True      True      5
# 36       False           True      True      5
# 37       False           True      True      5
# 38        True           True      True      5
# 39        True           True      True      5
# 40        True          False      True      5
# 41        True           True      True      5
# 42        True          False      True      5
# 43        True           True      True      5
# 44        True           True      True      5
# 45        True           True      True      5
# 46        True           True      True      5
# 47        True           True      True      5
# 48        True           True      True      4
# 49        True           True      True      4
# 50        True           True      True      4
# 51        True           True      True      4
# 52       False           True      True      4
# 53       False           True      True      4
# 54        True          False     False      4
# 55        True          False     False      4
# 56        True          False     False      4
# 57        True          False     False      4
# 58        True          False     False      4
# 59        True          False      True      4
# 60       False           True      True      4
# 61        True          False      True      4
# 62        True           True      True      4
# 63       False           True      True      4
# 64       False           True      True      4
# 65       False           True      True      4
# 66        True          False     False      4
# 67        True          False      True      4
# 68       False           True      True      4
# 69       False           True      True      4
# 70       False           True      True      4
# 71       False           True      True      4
# 72        True           True      True      4
# 73        True          False     False      4
# 74       False           True      True      4
# 75       False           True      True      4
# 76       False           True      True      4
# 77       False           True      True      4
# 78       False           True      True      4
# 79        True           True      True      4
# 80       False           True      True      3
# 81       False           True      True      3
# 82        True          False     False      3
# 83       False          False      True      3
# 84        True          False     False      3
# 85        True          False     False      3
# 86        True          False     False      3
# 87        True          False     False      3
# 88        True          False     False      3
# 89        True          False     False      3
# 90        True          False      True      3
# 91       False           True     False      3
# 92       False           True      True      3
# 93        True          False     False      3
# 94       False          False      True      3
# 95        True          False      True      3
# 96       False           True     False      3
# 97        True          False     False      3
# 98       False           True      True      3
# 99       False           True     False      3
# 100      False           True      True      3
